# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Tools for Data Science Assessment Notebook

# %% [markdown]
# ## Introduction
# <ul><li>List of data science languages</li>
#     <li>List of data science libraries</li>
#     <li>Data science tools</li>
#     <li>Code to convert minutes into hours</li>
#     <li>Author</li>
# </ul>

# %% [markdown]
# ### List of data science languages
# <ol>
#   <li>Python</li>
#   <li>R</li>
#   <li>SQL</li>
# </ol>

# %% [markdown]
# ### List of data science libraries
# <ol>
#   <li>Pandas</li>
#   <li>NumPy</li>
#   <li>Matplotlib</li>
# </ol>

# %% [markdown]
# ### Data science tools
#
# | Syntax      |
# | ----------- |
# | Jupyter Notebook |
# | IBM Watson Studio|
# | GitHub|
# | AWS Sage Maker|
# | R Studio|

# %% [markdown]
# ### Arithmetic expression example
#
# (5 + 7) * 4 = 48 <br>

# %%
print((5 + 7) * 4)
# Out:
# 48

# %%
#Code to convert minutes into hours
#This will convert 150 minutes to hours by diving by 60

min = 150
hrs = min / 60
print(hrs)
# Out:
# 2.5

# %% [markdown]
# ## Author - Saurabh Dua
